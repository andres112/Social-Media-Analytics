# %% [markdown]
# # Project 5 - Social Recommendation Systems (CiaoDVD Dataset)
# ## Continuation
# ### Tasks: 2. Implementation
# ### Task 2.2 Collaborative Filtering Recomender with Probabilistic Matrix Factorization.

# %%
import numpy as np
import time
import logging

from support import data_loading_analysis as dla
import model_based_cf as mbcf
from support import evaluation_metrics as em

from IPython.core.interactiveshell import InteractiveShell

# Used to get multiple outputs per cell
InteractiveShell.ast_node_interactivity = "all"

# Logging configuration
logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
# Adding a file to save the results
results_pmf = open('results/results_pmf1', 'a+')

# Loading the dataset
path = 'Ciao-DVD-Datasets/movie-ratings.txt'
data = dla.load_dataset(path, pmf=True)
dla.get_information(data)
# Remove this columns, is not required in analysis
data = data.drop('genreID', axis=1)
# Out:
# Users: 17615
# Movies: 16121
# Categories: 17
# Ratings count: 72665
# Density: 0.000256
# Sparsity: 0.999744

# %%
# Splitting the data into train(60%), validation(20%) and test(20%) sets
train_data, validation_data, test_data = dla.train_validate_test_split_pmf(data)
train_data.shape
validation_data.shape
test_data.shape
# Out:
# (43599, 3)
# (14533, 3)
# (14533, 3)

# %%
# Number of Users, Items(Movies)
num_users = data.userId.unique().shape[0]
num_items = data.movieId.unique().shape[0]

# Creating the rating matrix
rating_matrix = np.zeros([num_users, num_items])
for ele in train_data:
    rating_matrix[int(ele[0]), int(ele[1])] = float(ele[2])
rating_matrix.shape
# Out:
# (17615, 16121)

# %%
# Parameters settings
lambda_u = 0.02
lambda_v = 0.02
latent_dims = (5, 50)
learn_rate = 0.005
num_iters = 1000
bounds = (1, 5)

print('Parameters for the model are: \nlambda_u: {:f}, \nlambda_v: {:f}, '
      '\nLearning rate: {:f}, \nNumber of iterations: {:d}'.format(lambda_u, lambda_v, learn_rate,
                                                                   num_iters))
# Saving the parameters to a file
print('Parameters for the model are: \nlambda_u: {:f}, \nlambda_v: {:f}, \nLearning rate: {:f},'
      ' \nNumber of iterations: {:d}'.format(lambda_u, lambda_v, learn_rate, num_iters), file=results_pmf)
# Out:
# Parameters for the model are:
# lambda_u: 0.020000,
# lambda_v: 0.020000,
# Learning rate: 0.005000,
# Number of iterations: 10000

# %%
for latent_dim in range(latent_dims[0], latent_dims[1]+1, 1):
    # Constructing the PMF model
    logging.info('\nBuilding the PMF model with {:d} latent dimensions....'.format(latent_dim))
    # Saving the latent dimensions to a file
    print('\nPMF model with {:d} latent dimensions....'.format(latent_dim), file=results_pmf)

    time_start = time.time()
    pmf_model = mbcf.PMF(rating_matrix=rating_matrix, lambda_u=lambda_u, lambda_v=lambda_v, latent_dim=latent_dim,
                         learn_rate=learn_rate, momentum=0.9, num_iters=num_iters, seed=1)
    U, V = pmf_model.train(train_data=train_data, validation_data=validation_data)
    time_elapsed = time.time() - time_start
    logging.info('Completed model building in {0:.5f} seconds'.format(time_elapsed))

    # Saving the build time to a file
    print('Time to build model: {0:.5f} seconds'.format(time_elapsed), file=results_pmf)

    logging.info('Testing the PMF model with {:d} latent dimensions....'.format(latent_dim))
    time_start = time.time()
    predictions = pmf_model.predict(data=test_data)
    time_elapsed = time.time() - time_start
    logging.info('Completed model testing in {0:.5f} seconds'.format(time_elapsed))
    # Saving the test time to a file
    print('Time to test model: {0:.5f} seconds'.format(time_elapsed), file=results_pmf)

    # Transforming the data to be with in the bounds
    low, high = bounds
    predictions[predictions < low] = low
    predictions[predictions > high] = high

    # Calculating the RMSE and MAE between the test data and the predicted data
    test_rmse = em.RMSE(test_data[:, 2], predictions)
    test_mae = em.MAE(test_data[:, 2], predictions)

    print('RMSE on test data: {:f}'.format(test_rmse))
    print('MAE on test data: {:f}'.format(test_mae))

    # Saving the errors to a file
    print('RMSE on test data: {:f}'.format(test_rmse), file=results_pmf)
    print('MAE on test data: {:f}'.format(test_mae), file=results_pmf)
# Out:
# th 20 latent dimensions....
# RMSE on test data: 2.668683
# MAE on test data: 2.302857
# Iteration: 1, Loss: 725574.617336, Validation RMSE: 4.095505, Time: 20.360283 seconds
# Iteration: 2, Loss: 649993.327413, Validation RMSE: 3.907433, Time: 19.636598 seconds
# Iteration: 3, Loss: 578906.657012, Validation RMSE: 3.809660, Time: 19.282868 seconds
# Iteration: 4, Loss: 515569.701573, Validation RMSE: 3.683550, Time: 18.650082 seconds
# Iteration: 5, Loss: 441893.338311, Validation RMSE: 3.484563, Time: 18.460482 seconds
# Iteration: 6, Loss: 403159.092341, Validation RMSE: 3.392323, Time: 18.137632 seconds
# Completed model building in 135.98212 seconds
# Testing the PMF model with 20 latent dimensions....
# Completed model testing in 0.02600 seconds
#
# Building the PMF model with 21 latent dimensions....
# Iteration: 7, Loss: 379375.356846, Validation RMSE: 3.412982, Time: 19.170453 seconds
# The model converged at iteration:  7
# RMSE on test data: 2.659314
# MAE on test data: 2.290871
# Iteration: 1, Loss: 723276.917682, Validation RMSE: 4.089322, Time: 17.535738 seconds
# Iteration: 2, Loss: 645045.297216, Validation RMSE: 3.894923, Time: 18.355966 seconds
# Iteration: 3, Loss: 576870.656667, Validation RMSE: 3.811589, Time: 17.950932 seconds
# Iteration: 4, Loss: 512042.242165, Validation RMSE: 3.667596, Time: 17.797497 seconds
# Iteration: 5, Loss: 439160.614174, Validation RMSE: 3.475032, Time: 18.525951 seconds
# Iteration: 6, Loss: 393332.516601, Validation RMSE: 3.357808, Time: 19.031695 seconds
# Completed model building in 129.81607 seconds
# Testing the PMF model with 21 latent dimensions....
# Completed model testing in 0.02956 seconds
#
# Building the PMF model with 22 latent dimensions....
# Iteration: 7, Loss: 365680.199470, Validation RMSE: 3.360504, Time: 18.863859 seconds
# The model converged at iteration:  7
# RMSE on test data: 2.649004
# MAE on test data: 2.278110
# Iteration: 1, Loss: 720883.967065, Validation RMSE: 4.083245, Time: 19.211122 seconds
# Iteration: 2, Loss: 640422.971916, Validation RMSE: 3.883292, Time: 22.884664 seconds
# Iteration: 3, Loss: 576004.890506, Validation RMSE: 3.812847, Time: 18.684978 seconds
# Iteration: 4, Loss: 508238.849253, Validation RMSE: 3.647796, Time: 23.811054 seconds
# Iteration: 5, Loss: 437887.598922, Validation RMSE: 3.473283, Time: 19.423970 seconds
# Iteration: 6, Loss: 386898.399823, Validation RMSE: 3.337114, Time: 19.796156 seconds
# Completed model building in 144.82837 seconds
# Testing the PMF model with 22 latent dimensions....
# Completed model testing in 0.03237 seconds
#
# Building the PMF model with 23 latent dimensions....
#
# Building the PMF model with 31 latent dimensions....
# RMSE on test data: 2.975464
# MAE on test data: 2.693524
# Iteration: 1, Loss: 702009.960752, Validation RMSE: 4.031352, Time: 17.848829 seconds
# Iteration: 2, Loss: 604844.423559, Validation RMSE: 3.789846, Time: 22.575957 seconds
# Completed model building in 70.33916 seconds
# Testing the PMF model with 31 latent dimensions....
# Completed model testing in 0.04256 seconds
#
# Building the PMF model with 32 latent dimensions....
# Iteration: 3, Loss: 563276.379976, Validation RMSE: 3.814850, Time: 28.166263 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.968508
# MAE on test data: 2.684927
# Iteration: 1, Loss: 699427.524646, Validation RMSE: 4.024203, Time: 24.802207 seconds
# Iteration: 2, Loss: 600660.119534, Validation RMSE: 3.779070, Time: 20.359518 seconds
# Completed model building in 68.56778 seconds
# Testing the PMF model with 32 latent dimensions....
# Completed model testing in 0.03300 seconds
#
# Building the PMF model with 33 latent dimensions....
# Iteration: 3, Loss: 562356.728974, Validation RMSE: 3.815349, Time: 21.536845 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.961030
# MAE on test data: 2.675400
# Iteration: 1, Loss: 697697.827970, Validation RMSE: 4.019327, Time: 20.923364 seconds
# Iteration: 2, Loss: 597674.306058, Validation RMSE: 3.770325, Time: 21.031759 seconds
# Completed model building in 63.13114 seconds
# Testing the PMF model with 33 latent dimensions....
# Completed model testing in 0.03345 seconds
#
# Building the PMF model with 34 latent dimensions....
# Iteration: 3, Loss: 560799.436745, Validation RMSE: 3.814819, Time: 19.122855 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.954503
# MAE on test data: 2.667170
# Iteration: 1, Loss: 695306.017898, Validation RMSE: 4.012820, Time: 20.073834 seconds
# Iteration: 2, Loss: 594059.706462, Validation RMSE: 3.761484, Time: 19.176444 seconds
# Completed model building in 61.15356 seconds
# Testing the PMF model with 34 latent dimensions....
# Completed model testing in 0.03897 seconds
#
# Building the PMF model with 35 latent dimensions....
# Iteration: 3, Loss: 559388.017258, Validation RMSE: 3.811183, Time: 20.090740 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.946649
# MAE on test data: 2.657887
# Iteration: 1, Loss: 693600.669957, Validation RMSE: 4.008308, Time: 18.990248 seconds
# Iteration: 2, Loss: 591406.668253, Validation RMSE: 3.754340, Time: 18.632275 seconds
# Completed model building in 57.55550 seconds
# Testing the PMF model with 35 latent dimensions....
# Iteration: 3, Loss: 557962.398102, Validation RMSE: 3.810778, Time: 18.176540 seconds
# The model converged at iteration:  3
# Completed model testing in 0.88604 seconds
#
# Building the PMF model with 36 latent dimensions....
# RMSE on test data: 2.941502
# MAE on test data: 2.650833
# Iteration: 1, Loss: 691476.609468, Validation RMSE: 4.001972, Time: 21.546840 seconds
# Iteration: 2, Loss: 587821.480917, Validation RMSE: 3.744826, Time: 21.127176 seconds
# Completed model building in 64.04448 seconds
# Testing the PMF model with 36 latent dimensions....
# Completed model testing in 0.03436 seconds
#
# Building the PMF model with 37 latent dimensions....
# Iteration: 3, Loss: 556832.830148, Validation RMSE: 3.810858, Time: 19.523117 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.933642
# MAE on test data: 2.641247
# Iteration: 1, Loss: 689497.977601, Validation RMSE: 3.996533, Time: 18.719270 seconds
# Iteration: 2, Loss: 584957.926078, Validation RMSE: 3.736829, Time: 19.012807 seconds
# Completed model building in 59.32409 seconds
# Testing the PMF model with 37 latent dimensions....
# Completed model testing in 0.02875 seconds
#
# Building the PMF model with 38 latent dimensions....
# Iteration: 3, Loss: 554984.466644, Validation RMSE: 3.807354, Time: 19.680537 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.927561
# MAE on test data: 2.633328
# Iteration: 1, Loss: 687134.716419, Validation RMSE: 3.990093, Time: 20.028921 seconds
# Iteration: 2, Loss: 581702.417714, Validation RMSE: 3.728694, Time: 20.957946 seconds
# Completed model building in 64.80365 seconds
# Testing the PMF model with 38 latent dimensions....
# Completed model testing in 0.04113 seconds
#
# Building the PMF model with 39 latent dimensions....
# Iteration: 3, Loss: 553512.853632, Validation RMSE: 3.805387, Time: 21.992509 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.920076
# MAE on test data: 2.623718
# Iteration: 1, Loss: 685313.875521, Validation RMSE: 3.984849, Time: 21.888713 seconds
# Iteration: 2, Loss: 578721.367838, Validation RMSE: 3.720932, Time: 20.671141 seconds
# Completed model building in 65.25726 seconds
# Testing the PMF model with 39 latent dimensions....
# Completed model testing in 0.04384 seconds
#
# Building the PMF model with 40 latent dimensions....
# Iteration: 3, Loss: 552236.141725, Validation RMSE: 3.803589, Time: 20.663759 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.913744
# MAE on test data: 2.616477
# Iteration: 1, Loss: 683379.136833, Validation RMSE: 3.979296, Time: 44.612549 seconds
# Iteration: 2, Loss: 575902.715207, Validation RMSE: 3.712712, Time: 38.159554 seconds
# Completed model building in 107.55408 seconds
# Testing the PMF model with 40 latent dimensions....
# Iteration: 3, Loss: 550711.223796, Validation RMSE: 3.799326, Time: 22.602337 seconds
# The model converged at iteration:  3
# Completed model testing in 0.95781 seconds
#
# Building the PMF model with 41 latent dimensions....
# RMSE on test data: 2.907091
# MAE on test data: 2.607942
# Iteration: 1, Loss: 681318.326325, Validation RMSE: 3.973687, Time: 31.741724 seconds
# Iteration: 2, Loss: 573149.976205, Validation RMSE: 3.706629, Time: 22.905971 seconds
# Completed model building in 83.90653 seconds
# Testing the PMF model with 41 latent dimensions....
# Completed model testing in 0.05233 seconds
#
# Building the PMF model with 42 latent dimensions....
# Iteration: 3, Loss: 548688.712768, Validation RMSE: 3.799028, Time: 27.003058 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.901816
# MAE on test data: 2.601082
# Iteration: 1, Loss: 679583.924016, Validation RMSE: 3.969019, Time: 33.126892 seconds
# Iteration: 2, Loss: 570823.506720, Validation RMSE: 3.700234, Time: 23.887773 seconds
# Completed model building in 84.55348 seconds
# Testing the PMF model with 42 latent dimensions....
# Completed model testing in 0.03227 seconds
#
# Building the PMF model with 43 latent dimensions....
# Iteration: 3, Loss: 547388.917391, Validation RMSE: 3.795825, Time: 24.812906 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.896433
# MAE on test data: 2.594844
# Iteration: 1, Loss: 677096.254244, Validation RMSE: 3.962131, Time: 30.585831 seconds
# Iteration: 2, Loss: 567783.105134, Validation RMSE: 3.693000, Time: 43.651951 seconds
# Completed model building in 114.05856 seconds
# Testing the PMF model with 43 latent dimensions....
# Completed model testing in 0.04593 seconds
#
# Building the PMF model with 44 latent dimensions....
# Iteration: 3, Loss: 544956.790135, Validation RMSE: 3.787943, Time: 37.380852 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.889903
# MAE on test data: 2.586358
# Iteration: 1, Loss: 675365.377524, Validation RMSE: 3.957249, Time: 22.082188 seconds
# Iteration: 2, Loss: 565171.039204, Validation RMSE: 3.685025, Time: 21.888888 seconds
# Completed model building in 67.40434 seconds
# Testing the PMF model with 44 latent dimensions....
# Completed model testing in 0.04399 seconds
#
# Building the PMF model with 45 latent dimensions....
# Iteration: 3, Loss: 543322.029978, Validation RMSE: 3.786019, Time: 21.113274 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.884189
# MAE on test data: 2.579035
# Iteration: 1, Loss: 673067.699152, Validation RMSE: 3.950525, Time: 21.371312 seconds
# Iteration: 2, Loss: 562613.175863, Validation RMSE: 3.678398, Time: 18.900391 seconds
# Completed model building in 60.85975 seconds
# Testing the PMF model with 45 latent dimensions....
# Iteration: 3, Loss: 540808.542041, Validation RMSE: 3.778110, Time: 18.403956 seconds
# The model converged at iteration:  3
# Completed model testing in 0.62831 seconds
#
# Building the PMF model with 46 latent dimensions....
# RMSE on test data: 2.878384
# MAE on test data: 2.571839
# Iteration: 1, Loss: 671243.407849, Validation RMSE: 3.945196, Time: 19.432895 seconds
# Iteration: 2, Loss: 560081.675477, Validation RMSE: 3.671876, Time: 19.953674 seconds
# Completed model building in 61.56329 seconds
# Testing the PMF model with 46 latent dimensions....
# Completed model testing in 0.04670 seconds
#
# Building the PMF model with 47 latent dimensions....
# Iteration: 3, Loss: 538847.522207, Validation RMSE: 3.773129, Time: 20.208008 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.872952
# MAE on test data: 2.565095
# Iteration: 1, Loss: 669143.042944, Validation RMSE: 3.939326, Time: 19.951205 seconds
# Iteration: 2, Loss: 557623.564208, Validation RMSE: 3.665823, Time: 21.900956 seconds
# Completed model building in 64.85546 seconds
# Testing the PMF model with 47 latent dimensions....
# Completed model testing in 0.03100 seconds
#
# Building the PMF model with 48 latent dimensions....
# Iteration: 3, Loss: 537103.617149, Validation RMSE: 3.768200, Time: 21.019492 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.867111
# MAE on test data: 2.557829
# Iteration: 1, Loss: 667311.670475, Validation RMSE: 3.934104, Time: 22.216020 seconds
# Iteration: 2, Loss: 555807.191665, Validation RMSE: 3.660691, Time: 24.195943 seconds
# Completed model building in 71.52455 seconds
# Testing the PMF model with 48 latent dimensions....
# Completed model testing in 0.04800 seconds
#
# Building the PMF model with 49 latent dimensions....
# Iteration: 3, Loss: 534670.865663, Validation RMSE: 3.761577, Time: 23.201368 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.862049
# MAE on test data: 2.551015
# Iteration: 1, Loss: 665493.765229, Validation RMSE: 3.928950, Time: 24.444320 seconds
# Iteration: 2, Loss: 553250.632946, Validation RMSE: 3.653358, Time: 27.187614 seconds
# Completed model building in 77.15109 seconds
# Testing the PMF model with 49 latent dimensions....
# Completed model testing in 0.06172 seconds
#
# Building the PMF model with 50 latent dimensions....
# Iteration: 3, Loss: 533231.489610, Validation RMSE: 3.758177, Time: 23.257535 seconds
# The model converged at iteration:  3
# RMSE on test data: 2.856906
# MAE on test data: 2.545540
# Iteration: 1, Loss: 663454.570916, Validation RMSE: 3.923492, Time: 22.409266 seconds
# Iteration: 2, Loss: 551152.468148, Validation RMSE: 3.649685, Time: 21.500670 seconds
# Completed model building in 67.06242 seconds
# Testing the PMF model with 50 latent dimensions....
# Iteration: 3, Loss: 531214.442129, Validation RMSE: 3.753015, Time: 20.839717 seconds
# The model converged at iteration:  3
# Completed model testing in 1.00997 seconds
# RMSE on test data: 2.852636
# MAE on test data: 2.540180
